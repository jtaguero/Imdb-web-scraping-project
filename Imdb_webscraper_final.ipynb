# %%
import psycopg2 as pg2
from psycopg2 import extras
import time
import random

#Import beautiful soup
import requests
import re
from bs4 import BeautifulSoup

# %%
def vote_gross(container):
    gross_tot = None
    vote_s = None
    votes = container.find('p', class_ = 'sort-num_votes-visible')
    if votes:
        votes = votes.text
        votes = votes.replace('\n', ' ')
        votes = votes.replace('|', '')
        votes = votes.strip(" ")
        votes = votes.split(" ")
        votes = [i for i in votes if i]
        vote_s = None
        gross_tot = None
        if 'Votes:' in votes:
            votes_ind = votes.index('Votes:')
            if len(votes) >= votes_ind + 1:
                vote_s = int(votes[1].replace(',', ''))
                
            
                
        if len(votes) > 2:
            if votes[2] == 'Gross:':
                gross_tot = votes[3]
         
    return  vote_s, gross_tot

# %%
def names(container):
    
    global director
    global star
    name_list = []
    for elem in container(text=re.compile(r'Director')):
        if elem:
            name_list = elem.parent.text

            names = name_list.split('\n')
            names = [i for i in names if i] 
        
        
            names_s = []
            for name in names: 
                name_s = name.strip()
                name_s = name_s.strip(",")
                names_s.append(name_s)  
                names_s = [i for i in names_s if "|" not in i] 
            director = None
            star = None
            if len(names_s) > 1:
                if names_s[0][0:8] == 'Director':
                        director = names_s[1]
                if 'Stars:' in names_s:
                    star_ind = names_s.index('Stars:')
                    if star_ind:
                        star = names_s[star_ind + 1]

    
        
    return director, star

# %%
def insert(row):
#     """ insert a new row into the imdb2018 table """
    sql = """
        INSERT INTO imdb2018 (film_title, Imdb_num, Year, Runtime, Imdb_score, Metascore, Genres, MPAA_rating, Director, Actor, Votes, Gross) 
        VALUES %s
        """
    conn = None
    
    try:
        connection = pg2.connect(user = "johnaguero",
                                      password = "torTuosity2",
                                      host = "127.0.0.1",
                                      port = "5432",
                                      database = "films")
        c = connection.cursor()
        

        extras.execute_values(c, sql, row) 
        connection.commit()
        count = c.rowcount
        print (count)
    except (Exception, pg2.Error) as error :
        if(connection):
            print("Failed to insert record into mobile table", error)
    finally:
        #closing database connection.
        if(connection):
            c.close()
            connection.close()

# %%
def scrape(item_number, end_number):
    global vote_s
    global director
    global star
    
    vote_s = None
    director = None
    star = None
    
    while item_number < end_number:
    
        response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))

        soup = BeautifulSoup(response.text, 'html.parser')
        movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')

        

        dada = []
        for container in movie_containers:
            
            data = []
            title = container.h3.a
            if title:
                data.append(title.text)
            else:
                data.append(None)

            list_number = container.find('span', class_ = 'lister-item-index unbold text-primary')
            if list_number:
                list_number = list_number.text.replace(',', '')
                data.append(int(list_number.strip(".")))   
            else:
                data.append(None)

            year = container.h3.find('span', class_ = 'lister-item-year text-muted unbold')
            if year:

                data.append(year.text.strip("()"))
            else:
                data.append(None)

            runtime = container.find('span', class_ = 'runtime')
            if runtime:
                data.append(runtime.text.strip("()"))
            else:
                data.append(None)

            imdb_sc = container.strong
            if imdb_sc:
                data.append(float(imdb_sc.text.strip("()")))
            else:
                data.append(None)

            mscore = container.find('span', class_ = 'metascore favorable')
            if mscore:
                data.append(int(mscore.text))
            else:
                data.append(None)                

            genres = container.find('span', class_ = 'genre')
            if genres:
                data.append(genres.text.strip("\n"))
            else:
                data.append(None)                

            MPAA_rating = container.find('span', class_ = 'certificate')
            if MPAA_rating:
                data.append(MPAA_rating.text)
            else:
                data.append(None)    

            
            director, star = names(container)
            if director:
                data.append(director)
            else:
                data.append(None)

            if star:
                data.append(star)
            else:
                data.append(None)                
            votes = None
            vote_s = None
            votes, gross = vote_gross(container)

            if votes:
                data.append(votes)            
            else:
                data.append(None)

            if gross:
                data.append(gross)                
            else:
                data.append(None)
                
            data = tuple(data)    
            
            dada.append(data)
            
            
            
        item_number = item_number + 50
        
        print(dada)
        insert(dada)    

        time.sleep(random.randint(5,30))    

    pass

# %%
scrape(1151, 1201)
# Out:
# [('Dear Ex', 1151, '2018', '100 min', 7.4, None, 'Comedy, Drama, Romance            ', 'TV-MA', 'Chih-Yen Hsu', 'Roy Chiu', 2240, None), ('Brother of the Year', 1152, '2018', '125 min', 6.7, None, 'Comedy, Drama, Romance            ', None, 'Witthaya Thongyooyong', 'Sunny Suwanmethanont', 1133, None), ('Ulysses: A Dark Odyssey', 1153, '2018', '110 min', 8.3, None, 'Action, Crime, Drama            ', None, 'Federico Alotto', 'Danny Glover', 1528, None), ('The Misguided', 1154, '2018', '88 min', 7.9, None, 'Comedy, Drama            ', None, 'Shannon Alexander', 'Caleb Galati', 389, None), ('Les estivants', 1155, '2018', '127 min', 5.5, None, 'Comedy, Drama            ', None, 'Valeria Bruni Tedeschi', 'Valeria Bruni Tedeschi', 231, None), ('Kaalakaandi', 1156, '2018', '112 min', 6.2, None, 'Comedy, Thriller            ', None, 'Akshat Verma', 'Saif Ali Khan', 1941, None), ('Huckleberry', 1157, '2018', '80 min', 7.6, None, 'Drama, Thriller            ', None, 'Roger Hill', 'Daniel Fisher-Golden', 59, None), ('Animal', 1158, 'II) (2018', '112 min', 6.2, None, 'Drama, Thriller            ', 'TV-MA', 'Armando Bo', 'Guillermo Francella', 967, None), ('Sibel', 1159, '2018', '95 min', 7.2, 65, 'Drama            ', None, 'Guillaume Giovanetti', 'Damla Sönmez', 846, None), ('Electric Love', 1160, '2018', '81 min', 5.2, None, 'Comedy            ', None, 'Aaron Fradkin', 'Mia Serafino', 187, None), ('All You Ever Wished For', 1161, '2018', '86 min', 4.1, None, 'Fantasy, Romance            ', None, 'Barry Morrow', 'Claudio Bigagli', 115, None), ('Viper Club', 1162, '2018', '109 min', 5.5, None, 'Drama            ', 'R', 'Maryam Keshavarz', 'Susan Sarandon', 412, '$0.06M'), ('All the Creatures Were Stirring', 1163, '2018', '80 min', 4.9, None, 'Horror            ', 'Not Rated', 'David Ian McKendry', 'Constance Wu', 680, None), ('Spivak', 1164, '2018', '91 min', 5.5, None, 'Comedy            ', 'TV-MA', 'Anthony Abrams', 'Michael Bacall', 431, None), ('Kucumbu tubuh indahku', 1165, '2018', '105 min', 7.3, None, 'Drama            ', None, 'Garin Nugroho', 'Muhammad Khan', 197, None), ('Kupi menya', 1166, '2018', '107 min', 5.4, None, 'Drama            ', 'Unrated', 'Vadim Perelman', 'Anna Adamovich', 231, None), ('Off the Menu', 1167, '2018', '96 min', 5.6, None, 'Comedy, Romance            ', 'Not Rated', 'Jay Silverman', 'Santino Fontana', 494, None), ('The Curse of Lilith Ratchet', 1168, '2018', '104 min', 2.9, None, 'Horror            ', None, 'Eddie Lengyel', 'KateLynn E. Newberry', 135, None), ('Genesis', 1169, 'II) (2018', '114 min', 3.2, None, 'Sci-Fi            ', None, 'Freddie Hutton-Mills', 'Olivia Grant', 793, None), ('Fly By Night', 1170, '2018', '100 min', 6.2, None, 'Crime, Drama            ', None, 'Zahir Omar', 'Bront Palarae', 80, None), ('Christmas Camp', 1171, '2018', '90 min', 6.1, None, 'Drama, Family, Romance            ', None, 'Jeff Fisher', 'Lily Anne Harrison', 195, None), ('Cake', 1172, 'I) (2018', '125 min', 7.5, None, 'Drama, Mystery, Romance            ', 'Not Rated', 'Asim Abbasi', 'Aamina Sheikh', 733, None), ('Ailecek Saskiniz', 1173, '2018', '113 min', 6.4, None, 'Comedy            ', None, 'Selçuk Aydemir', 'Ahmet Kural', 4998, None), ('C/o Kancharapalem', 1174, '2018', '152 min', 9.1, None, 'Drama            ', None, 'Maha Venkatesh', 'Radha Bessy', 2484, None), ('Neo-eui kyeol-hoon-sik', 1175, '2018', '110 min', 6.8, None, 'Romance            ', None, 'Seok-Geun Lee', 'Bo-Young Park', 1092, None), ('Gojira: hoshi wo kû mono', 1176, '2018', '91 min', 4.9, None, 'Animation, Action, Adventure            ', 'TV-14', 'Hiroyuki Seshita', 'Mamoru Miyano', 2754, None), ('Un homme pressé', 1177, '2018', '100 min', 6.3, None, 'Comedy, Drama            ', None, 'Hervé Mimran', 'Fabrice Luchini', 684, None), ('Hospitality', 1178, '2018', '80 min', 4.5, None, 'Crime, Drama, Thriller            ', 'Not Rated', 'Nick Chakwin', 'Emmanuelle Chriqui', 197, None), ('Miss Arizona', 1179, '2018', '94 min', 4.8, None, 'Comedy, ...
# Failed to insert record into mobile table duplicate key value violates unique constraint "imdb2018_pkey"
# DETAIL:  Key (imdb_num)=(1151) already exists.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-c5f555d48c13> in <module>()
# ----> 1 scrape(1151, 1201)
#       2
#
# <ipython-input-27-6edf7a24c9c7> in scrape(item_number, end_number)
#     107         insert(dada)
#     108
# --> 109         time.sleep(random.randint(5,30))
#     110
#     111     pass
#
# KeyboardInterrupt:

# %%
item_number = 1
response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))

soup = BeautifulSoup(response.text, 'html.parser')
movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')





movie_containers[0].find('span', class_ = 'lister-item-index unbold text-primary').text.strip(".")

# %%
# def scrape(item_number):
    
    
    
#     response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))
    
#     soup = BeautifulSoup(response.text, 'html.parser')
#     movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
    
    

    

    
#     for container in movie_containers:
#         data = []
#         title = container.h3.a
#         if title:
#             data.append(title.text)
#         else:
#             data.append(None)

#         list_number = container.find('span', class_ = 'lister-item-index unbold text-primary')
#         if list_number:
#             data.append(int(list_number.text.strip(".")))   
#         else:
#             data.append(None)

#         year = container.h3.find('span', class_ = 'lister-item-year text-muted unbold')
#         if year:

#             data.append(year.text.strip("()"))
#         else:
#             data.append(None)

#         runtime = container.find('span', class_ = 'runtime')
#         if runtime:
#             data.append(runtime.text.strip("()"))
#         else:
#             data.append(None)

#         imdb_sc = container.strong
#         if imdb_sc:
#             data.append(float(imdb_sc.text.strip("()")))
#         else:
#             data.append(None)

#         mscore = container.find('span', class_ = 'metascore favorable')
#         if mscore:
#             data.append(int(mscore.text))
#         else:
#             data.append(None)                

#         genres = container.find('span', class_ = 'genre')
#         if genres:
#             data.append(genres.text.strip("\n"))
#         else:
#             data.append(None)                

#         MPAA_rating = container.find('span', class_ = 'certificate')
#         if MPAA_rating:
#             data.append(MPAA_rating.text)
#         else:
#             data.append(None)    


#         director, star = names(container)
#         if director:
#             data.append(director)
#         else:
#             data.append(None)

#         if star:
#             data.append(star)
#         else:
#             data.append(None)                


#         votes, gross = vote_gross(container)

#         if votes:
#             data.append(int(votes.strip(",")) )            
#         else:
#             data.append(None)

#         if gross:
#             data.append(gross)                
#         else:
#             data.append(None)

# %%
# def scrape(item_number):
    
    
    
#     response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))
    
#     soup = BeautifulSoup(response.text, 'html.parser')
#     movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
    
    

#     fields['link'] = tag['href']
#     fields['u_id'] = tag['data-id']
#     fields['title'] = tag.text

    
#     for container in movie_containers:
#         fields = {}
#         title = container.h3.a
#         if title:
#             fields['Film title'] = title.text
#         else:
#             data.append(None)

#         list_number = container.find('span', class_ = 'lister-item-index unbold text-primary')
#         if list_number:
#             fields['Imdb 2018 list number'] = (int(list_number.text.strip(".")))   
#         else:
#             data.append(None)

#         year = container.h3.find('span', class_ = 'lister-item-year text-muted unbold')
#         if year:
#             fields['Year released'] = year.text.strip("()")
            

            
#         else:
#             data.append(None)

#         runtime = container.find('span', class_ = 'runtime')
#         if runtime:
#             fields['Runtime'] = runtime.text.strip("()"))
#         else:
#             data.append(None)

#         imdb_sc = container.strong
#         if imdb_sc:
#             fields['Imdb Score'] = float(imdb_sc.text.strip("()"))
#         else:
#             data.append(None)

#         mscore = container.find('span', class_ = 'metascore favorable')
#         if mscore:
#             fields['Metascore'] = (int(mscore.text))
#         else:
#             data.append(None)                

#         genres = container.find('span', class_ = 'genre')
#         if genres:
#             fields['Genres'] = genres.text.strip("\n")
#         else:
#             data.append(None)                

#         MPAA_rating = container.find('span', class_ = 'certificate')
#         if MPAA_rating:
#             fields['MPAA rating'] = MPAA_rating.text
#         else:
#             data.append(None)    


#         directors, stars = names(container)
#         if directors:
#             fields['Director(s)'] = directors
#         else:
#             data.append(None)

#         if stars:
#             fields['Actor(s)'] = stars
#         else:
#             data.append(None)                


#         votes, gross = vote_gross(container)

#         if votes:
#             fields['Votes'] = int(votes.strip(","))           
#         else:
#             data.append(None)

#         if gross:
#             fields['Gross'] = gross                
#         else:
#             data.append(None)

#         store_in_db()
        
#         time.sleep(random.randint(5,30))
