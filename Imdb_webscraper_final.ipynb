# %%
import psycopg2 as pg2
from psycopg2 import extras
import time
import random

#Import beautiful soup
import requests
import re
from bs4 import BeautifulSoup

# %%
def vote_gross(container):
    gross_tot = None
    vote_s = None
    votes = container.find('p', class_ = 'sort-num_votes-visible')
    if votes:
        votes = votes.text
        votes = votes.replace('\n', ' ')
        votes = votes.replace('|', '')
        votes = votes.strip(" ")
        votes = votes.split(" ")
        votes = [i for i in votes if i]
        vote_s = None
        gross_tot = None
        if 'Votes:' in votes:
            votes_ind = votes.index('Votes:')
            if len(votes) >= votes_ind + 1:
                vote_s = int(votes[1].replace(',', ''))
                
            
                
        if len(votes) > 2:
            if votes[2] == 'Gross:':
                gross_tot = votes[3]
         
    return  vote_s, gross_tot

# %%
def names(container):
    
    global director
    global star
    name_list = []
    for elem in container(text=re.compile(r'Director')):
        if elem:
            name_list = elem.parent.text

            names = name_list.split('\n')
            names = [i for i in names if i] 
        
        
            names_s = []
            for name in names: 
                name_s = name.strip()
                name_s = name_s.strip(",")
                names_s.append(name_s)  
                names_s = [i for i in names_s if "|" not in i] 
            director = None
            star = None
            if len(names_s) > 1:
                if names_s[0][0:8] == 'Director':
                        director = names_s[1]
                if 'Stars:' in names_s:
                    star_ind = names_s.index('Stars:')
                    if star_ind:
                        star = names_s[star_ind + 1]

    
        
    return director, star

# %%
def insert(row):
#     """ insert a new row into the imdb2018 table """
    sql = """
        INSERT INTO imdb2018_meta
        VALUES (%s, %s, %s)
        """
    conn = None
    
    try:
        connection = pg2.connect(user = "johnaguero",
                                      password = "torTuosity2",
                                      host = "127.0.0.1",
                                      port = "5432",
                                      database = "films")
        c = connection.cursor()
        
        
        c.execute(sql, row) 
        connection.commit()
        count = c.rowcount
        print (count)
    except (Exception, pg2.Error) as error :
        if(connection):
            print("Failed to insert record into mobile table", error)
    finally:
        #closing database connection.
        if(connection):
            c.close()
            connection.close()

# %%
def scrape(item_number, end_number):
    global vote_s
    global director
    global star
    
    vote_s = None
    director = None
    star = None
    
    while item_number < end_number:
    
        response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))

        soup = BeautifulSoup(response.text, 'html.parser')
        movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')

        

#         dada = []
        for container in movie_containers:
            
            data = []
            
            title = container.h3.a
            if title:
                data.append(title.text)
            else:
                data.append(None)


            list_number = container.find('span', class_ = 'lister-item-index unbold text-primary')
            if list_number:
                list_number = list_number.text.replace(',', '')
                data.append(int(list_number.strip(".")))   
            else:
                data.append(None)

               

                        
            for elem in container(text=re.compile(r'Metascore')):
                if elem:
                    
                    data.append(int(elem.parent.text[1:3]))
                else:
                    data.append(None) 
                
            data = tuple(data)    
            
            print(data)
            insert(data)
        
        item_number += 50
            
            

        
               
        
        time.sleep(random.randint(5,30))    

    pass

# %%
scrape(201, 2000)
# Out:
# ('The Command', 201, 55)
# 1
# ('Goosebumps 2: Haunted Halloween', 202, 53)
# 1
# ('Swiped', 203)
# Failed to insert record into mobile table tuple index out of range
# ('Arizona', 204, 41)
# 1
# ('Level 16', 205, 46)
# 1
# ('The Open House', 206)
# Failed to insert record into mobile table tuple index out of range
# ('How It Ends', 207, 36)
# 1
# ('Mission of Honor', 208)
# Failed to insert record into mobile table tuple index out of range
# ('Unsane', 209, 63)
# 1
# ('The House with a Clock in Its Walls', 210, 57)
# 1
# ('Tell It to the Bees', 211, 50)
# 1
# ('Colette', 212, 74)
# 1
# ('I Feel Pretty', 213, 48)
# 1
# ('The White Crow', 214, 61)
# 1
# ('Astérix: Le secret de la potion magique', 215)
# Failed to insert record into mobile table tuple index out of range
# ('Ophelia', 216, 60)
# 1
# ("At Eternity's Gate", 217, 76)
# 1
# ('The Night Comes for Us', 218, 69)
# 1
# ('Lords of Chaos', 219, 48)
# 1
# ('Transit', 220, 82)
# 1
# ('Set It Up', 221, 62)
# 1
# ('Slender Man', 222, 30)
# 1
# ('Life of the Party', 223, 46)
# 1
# ('Incident in a Ghostland', 224, 44)
# 1
# ('Forever My Girl', 225, 36)
# 1
# ('Insidious: The Last Key', 226, 49)
# 1
# ('Hold the Dark', 227, 63)
# 1
# ('Gloria Bell', 228, 79)
# 1
# ('Welcome Home', 229, 38)
# 1
# ('Teen Spirit', 230, 57)
# 1
# ('Anon', 231, 54)
# 1
# ('Ballon', 232)
# Failed to insert record into mobile table tuple index out of range
# ('Out of Blue', 233, 49)
# 1
# ('A.I. Rising', 234)
# Failed to insert record into mobile table tuple index out of range
# ('Trial by Fire', 235, 51)
# 1
# ("Yesterday's Girl", 236)
# Failed to insert record into mobile table tuple index out of range
# ('The Front Runner', 237, 61)
# 1
# ('King of Thieves', 238, 47)
# 1
# ('Cold War', 239, 90)
# 1
# ('The Clovehitch Killer', 240, 59)
# 1
# ('The Kindergarten Teacher', 241, 75)
# 1
# ('Game Over, Man!', 242, 32)
# 1
# ('The Miseducation of Cameron Post', 243, 69)
# 1
# ('Then Came You', 244, 44)
# 1
# ('Sierra Burgess Is a Loser', 245, 60)
# 1
# ('One Last Thing', 246)
# Failed to insert record into mobile table tuple index out of range
# ('Aniara', 247, 60)
# 1
# ('Giant Little Ones', 248, 67)
# 1
# ('The 15:17 to Paris', 249, 45)
# 1
# ('Stockholm', 250, 54)
# 1
# ('A-X-L', 251, 29)
# 1
# ('Gwen', 252, 63)
# 1
# ('A Futile and Stupid Gesture', 253, 55)
# 1
# ('Holiday', 254, 78)
# 1
# ('Midnight Sun', 255, 38)
# 1
# ('The Little Mermaid', 256)
# Failed to insert record into mobile table tuple index out of range
# ('Every Day', 257, 52)
# 1
# ('A Private War', 258, 75)
# 1
# ('Peter Rabbit', 259, 51)
# 1
# ('Final Score', 260, 53)
# 1
# ('Down a Dark Hall', 261, 56)
# 1
# ('Ben Is Back', 262, 66)
# 1
# ('22 July', 263, 69)
# 1
# ('The Week Of', 264, 41)
# 1
# ('The Competition', 265)
# Failed to insert record into mobile table tuple index out of range
# ('The Package', 266)
# Failed to insert record into mobile table tuple index out of range
# ('Occupation', 267, 45)
# 1
# ('Action Point', 268, 36)
# 1
# ('Dogman', 269, 71)
# 1
# ('Hot Air', 270, 32)
# 1
# ('Gringo', 271, 46)
# 1
# ('I Can Only Imagine', 272, 30)
# 1
# ('When We First Met', 273, 36)
# 1
# ('211', 274, 21)
# 1
# ('Winchester', 275, 28)
# 1
# ('K.G.F: Chapter 1', 276)
# Failed to insert record into mobile table tuple index out of range
# ('The Public', 277, 46)
# 1
# ('The Strangers: Prey at Night', 278, 48)
# 1
# ('The Titan', 279, 33)
# 1
# ('The Axiom', 280)
# Failed to insert record into mobile table tuple index out of range
# ('Journal 64', 281)
# Failed to insert record into mobile table tuple index out of range
# ('Dragon Ball Super: Broly', 282, 59)
# 1
# ('Find Me', 283)
# Failed to insert record into mobile table tuple index out of range
# ('Tau', 284, 43)
# 1
# ('American Animals', 285, 68)
# 1
# ('Speed Kills', 286, 19)
# 1
# ('Between Worlds', 287, 24)
# 1
# ('A Dark Place', 288, 41)
# 1
# ('Teen Titans Go! To the Movies', 289, 69)
# 1
# ('Elizabeth Harvest', 290, 54)
# 1
# ('Ratsasan', 291)
# Failed to insert record into mobile table tuple index out of range
# ('Da hong zha', 292)
# Failed to insert record into mobile table tuple index out of range
# ('The Outsider', 293, 30)
# 1
# ('Blindspotting', 294, 77)
# 1
# ('Braven', 295, 61)
# 1
# ('Grâce à Dieu', 296, 76)
# 1
# ('Fast Color', 297, 65)
# 1
# ('Unfriended: Dark Web', 298, 53)
# 1
# ('Kin', 299, 35)
# 1
# ('Breaking In', 300, 42)
# 1
# ('Galveston', 301, 57)
# 1
# ('The Little Stranger', 302, 67)
# 1
# ('Super Troopers 2', 303, 41)
# 1
# ('Cam', 304, 71)
# 1
# ('Uncle Drew', 305, 57)
# 1
# ('Ibiza', 306, 56)
# 1
# ('Zero', 307)
# Failed to insert record into mobile table tuple index out of range
# ('Hell Fest', 308, 26)
# 1
# ('Girls with Balls', 309)
# Failed to insert record into mobile table tuple index out of range
# ('Birds of Passage', 310, 85)
# 1
# ('The Tale', 311, 90)
# 1
# ('The Hurricane Heist', 312, 35)
# 1
# ('Fahrenheit 451', 313)
# Failed to insert record into mobile table tuple index out of range
# ('Beloved Beast', 314)
# Failed to insert record into mobile table tuple index out of range
# ('Office Uprising', 315)
# Failed to insert record into mobile table tuple index out of range
# ('Stree', 316)
# Failed to insert record into mobile table tuple index out of range
# ('Lizzie', 317, 59)
# 1
# ('Girl', 318, 73)
# 1
# ("He's Out There", 319)
# Failed to insert record into mobile table tuple index out of range
# ('Double Lives', 320, 79)
# 1
# ('The Miracle Season', 321, 44)
# 1
# ('D-Railed', 322)
# Failed to insert record into mobile table tuple index out of range
# ('American Dreamer', 323)
# Failed to insert record into mobile table tuple index out of range
# ("Summer '03", 324, 45)
# 1
# ('Loro', 325, 51)
# 1
# ('Damsel', 326, 63)
# 1
# ('T-34', 327)
# Failed to insert record into mobile table tuple index out of range
# ('Ahlat Agaci', 328, 86)
# 1
# ('Acts of Violence', 329, 28)
# 1
# ('The Catcher Was a Spy', 330, 49)
# 1
# ("La chute de l'empire américain", 331, 55)
# 1
# ('Like Father', 332, 52)
# 1
# ('The Last Man', 333)
# Failed to insert record into mobile table tuple index out of range
# ('Time Freak', 334)
# Failed to insert record into mobile table tuple index out of range
# ('Thunder Road', 335, 79)
# 1
# ('Mia and the White Lion', 336, 52)
# 1
# ('Tumbbad', 337)
# Failed to insert record into mobile table tuple index out of range
# ('Thugs of Hindostan', 338)
# Failed to insert record into mobile table tuple index out of range
# ('Blaze', 339, 75)
# 1
# ("Nobody's Fool", 340, 39)
# 1
# ('Sherlock Gnomes', 341, 36)
# 1
# ('Matriarch', 342)
# Failed to insert record into mobile table tuple index out of range
# ("I Think We're Alone Now", 343, 51)
# 1
# ('Running Out Of Time', 344)
# Failed to insert record into mobile table tuple index out of range
# ('White Chamber', 345)
# Failed to insert record into mobile table tuple index out of range
# ('The Angel', 346)
# Failed to insert record into mobile table tuple index out of range
# ('Cutterhead', 347)
# Failed to insert record into mobile table tuple index out of range
# ('Big Kill', 348, 42)
# 1
# ('The Golem', 349, 63)
# 1
# ('Head Full of Honey', 350)
# Failed to insert record into mobile table tuple index out of range
# ('Reprisal', 351, 19)
# 1
# ('Yip Man ngoi zyun: Cheung Tin Chi', 352, 72)
# 1
# ("All the Devil's Men", 353, 27)
# 1
# ('The Dark', 354, 52)
# 1
# ("L'homme fidèle", 355, 68)
# 1
# ('Possum', 356, 64)
# 1
# ('SuperFly', 357, 52)
# 1
# ('Bad Samaritan', 358, 42)
# 1
# ('Back Roads', 359, 42)
# 1
# ('Malevolent', 360)
# Failed to insert record into mobile table tuple index out of range
# ('What Keeps You Alive', 361, 66)
# 1
# ('Family', 362, 60)
# 1
# ('Donnybrook', 363, 53)
# 1
# ('Delirium', 364)
# Failed to insert record into mobile table tuple index out of range
# ('Stuck', 365)
# Failed to insert record into mobile table tuple index out of range
# ('Zoe', 366, 39)
# 1
# ('Acrimony', 367, 32)
# 1
# ('The VelociPastor', 368)
# Failed to insert record into mobile table tuple index out of range
# ("I'll Take Your Dead", 369)
# Failed to insert record into mobile table tuple index out of range
# ('Backtrace', 370)
# Failed to insert record into mobile table tuple index out of range
# ('Involution', 371)
# Failed to insert record into mobile table tuple index out of range
# ('Samson', 372, 17)
# 1
# ('Wildling', 373, 58)
# 1
# ('Rosie', 374, 83)
# 1
# ('Gangsta', 375)
# Failed to insert record into mobile table tuple index out of range
# ('Beirut', 376, 69)
# 1
# ('Jeremiah Terminator LeRoy', 377, 55)
# 1
# ('The Head Hunter', 378)
# Failed to insert record into mobile table tuple index out of range
# ('The Isle', 379)
# Failed to insert record into mobile table tuple index out of range
# ('Peterloo', 380, 66)
# 1
# ('Canal Street', 381)
# Failed to insert record into mobile table tuple index out of range
# ('Duck Butter', 382, 58)
# 1
# ('Running for Grace', 383)
# Failed to insert record into mobile table tuple index out of range
# ('Traffik', 384, 37)
# 1
# ('American Kamasutra', 385)
# Failed to insert record into mobile table tuple index out of range
# ('Father of the Year', 386, 32)
# 1
# ('7 Days in Entebbe', 387, 49)
# 1
# ('Jurassic Galaxy', 388)
# Failed to insert record into mobile table tuple index out of range
# ('The Seagull', 389, 58)
# 1
# ('Calibre', 390, 76)
# 1
# ('1st Summoning', 391)
# Failed to insert record into mobile table tuple index out of range
# ('The Festival', 392, 57)
# 1
# ('Beyond White Space', 393)
# Failed to insert record into mobile table tuple index out of range
# ('Brian Banks', 394, 58)
# 1
# ('The Chaperone', 395, 48)
# 1
# ('The Mercy', 396, 60)
# 1
# ('Mou seung', 397)
# Failed to insert record into mobile table tuple index out of range
# ('Looking Glass', 398, 33)
# 1
# ('The Happy Prince', 399, 64)
# 1
# ('Message Man', 400)
# Failed to insert record into mobile table tuple index out of range
# ('Primal Rage: The Legend of Konga', 401)
# Failed to insert record into mobile table tuple index out of range
# ('Piercing', 402, 63)
# 1
# ('Little Woods', 403, 74)
# 1
# ('2036 Origin Unknown', 404)
# Failed to insert record into mobile table tuple index out of range
# ('Sometimes Always Never', 405)
# Failed to insert record into mobile table tuple index out of range
# ('The Christmas Chronicles', 406, 52)
# 1
# ('Pihu', 407)
# Failed to insert record into mobile table tuple index out of range
# ('Jiang hu er nü', 408, 85)
# 1
# ('Sobibor', 409)
# Failed to insert record into mobile table tuple index out of range
# ('Le grand bain', 410)
# Failed to insert record into mobile table tuple index out of range
# ('Await Further Instructions', 411)
# Failed to insert record into mobile table tuple index out of range
# ('Future World', 412, 10)
# 1
# ('Skjelvet', 413, 70)
# 1
# ('Dog Days', 414, 47)
# 1
# ('Cebimdeki Yabanci', 415)
# Failed to insert record into mobile table tuple index out of range
# ('Baby Girl', 416)
# Failed to insert record into mobile table tuple index out of range
# ('Redcon-1', 417)
# Failed to insert record into mobile table tuple index out of range
# ('In Darkness', 418, 59)
# 1
# ('Geetha Govindam', 419)
# Failed to insert record into mobile table tuple index out of range
# ('Happy as Lazzaro', 420, 87)
# 1
# ('The Mountain', 421, 64)
# 1
# ('Higher Power', 422)
# Failed to insert record into mobile table tuple index out of range
# ('The Emperor of Paris', 423)
# Failed to insert record into mobile table tuple index out of range
# ('Di qiu zui hou de ye wan', 424, 89)
# 1
# ('Private Life', 425, 83)
# 1
# ('Early Man', 426, 68)
# 1
# ('I Still See You', 427, 31)
# 1
# ('Alien Invasion', 428)
# Failed to insert record into mobile table tuple index out of range
# ('Darker Than Night', 429)
# Failed to insert record into mobile table tuple index out of range
# ('Bent', 430)
# Failed to insert record into mobile table tuple index out of range
# ('Ang babaeng allergic sa wifi', 431)
# Failed to insert record into mobile table tuple index out of range
# ('Monster Party', 432, 58)
# 1
# ('Twisted Pair', 433)
# Failed to insert record into mobile table tuple index out of range
# ('The Other Side of the Wind', 434, 78)
# 1
# ('Alex Strangelove', 435, 62)
# 1
# ('The Oath', 436, 58)
# 1
# ('The Con Is On', 437)
# Failed to insert record into mobile table tuple index out of range
# ('El Chicano', 438, 46)
# 1
# ('Scarborough', 439, 50)
# 1
# ('Josie', 440, 31)
# 1
# ('The Domestics', 441)
# Failed to insert record into mobile table tuple index out of range
# ('What They Had', 442, 69)
# 1
# ('Mapplethorpe', 443, 42)
# 1
# ('El Angel', 444, 61)
# 1
# ('Puppet Master: The Littlest Reich', 445, 52)
# 1
# ('Dude', 446)
# Failed to insert record into mobile table tuple index out of range
# ('Avengers of Justice: Farce Wars', 447)
# Failed to insert record into mobile table tuple index out of range
# ('The Final Wish', 448)
# Failed to insert record into mobile table tuple index out of range
# ('2.0', 449)
# Failed to insert record into mobile table tuple index out of range
# ('Tel Aviv on Fire', 450, 70)
# 1
# ('Puppy Love', 451)
# Failed to insert record into mobile table tuple index out of range
# ('The Neighbor', 452)
# Failed to insert record into mobile table tuple index out of range
# ('Eat Me', 453)
# Failed to insert record into mobile table tuple index out of range
# ('Little Women', 454, 40)
# 1
# ('Support the Girls', 455, 85)
# 1
# ('We Belong Together', 456)
# Failed to insert record into mobile table tuple index out of range
# ('Leto', 457, 69)
# 1
# ('Blue Night', 458, 45)
# 1
# ('100 Dinge', 459)
# Failed to insert record into mobile table tuple index out of range
# ('Next Gen', 460)
# Failed to insert record into mobile table tuple index out of range
# ('Day of the Dead: Bloodline', 461)
# Failed to insert record into mobile table tuple index out of range
# ("Alad'2", 462)
# Failed to insert record into mobile table tuple index out of range
# ('Boarding School', 463, 45)
# 1
# ('Mara', 464, 32)
# 1
# ('10x10', 465)
# Failed to insert record into mobile table tuple index out of range
# ('Burden', 466, 63)
# 1
# ('Ashes in the Snow', 467, 43)
# 1
# ('Our House', 468, 45)
# 1
# ('Spinning Man', 469, 44)
# 1
# ('El reino', 470)
# Failed to insert record into mobile table tuple index out of range
# ('The Basement', 471, 27)
# 1
# ('Lykke-Per', 472)
# Failed to insert record into mobile table tuple index out of range
# ('In This Gray Place', 473)
# Failed to insert record into mobile table tuple index out of range
# ('Accident Man', 474)
# Failed to insert record into mobile table tuple index out of range
# ('The Tree of Blood', 475)
# Failed to insert record into mobile table tuple index out of range
# ('The Pretenders', 476)
# Failed to insert record into mobile table tuple index out of range
# ('Kickboxer: Retaliation', 477, 54)
# 1
# ('Head Count', 478, 49)
# 1
# ('Irreplaceable You', 479, 34)
# 1
# ('Silver Lake', 480)
# Failed to insert record into mobile table tuple index out of range
# ('14 Cameras', 481, 25)
# 1
# ('The Princess Switch', 482)
# Failed to insert record into mobile table tuple index out of range
# ('You Might Be the Killer', 483)
# Failed to insert record into mobile table tuple index out of range
# ('Starfish', 484, 74)
# 1
# ('The Dead Center', 485)
# Failed to insert record into mobile table tuple index out of range
# ('Mirai', 486, 81)
# 1
# ('The Bouncer', 487)
# Failed to insert record into mobile table tuple index out of range
# ('Patrick', 488, 28)
# 1
# ('Cyrano, My Love', 489)
# Failed to insert record into mobile table tuple index out of range
# ('Ideal Home', 490, 62)
# 1
# ('The Row', 491)
# Failed to insert record into mobile table tuple index out of range
# ('Benjamin', 492)
# Failed to insert record into mobile table tuple index out of range
# ('Isabelle', 493, 26)
# 1
# ('Farming', 494)
# Failed to insert record into mobile table tuple index out of range
# ('Status Update', 495)
# Failed to insert record into mobile table tuple index out of range
# ('The Third Wife', 496, 71)
# 1
# ('Patient Zero', 497)
# Failed to insert record into mobile table tuple index out of range
# ('A Twelve-Year Night', 498)
# Failed to insert record into mobile table tuple index out of range
# ('Being Frank', 499, 41)
# 1
# ('Paul, Apostle of Christ', 500, 52)
# 1
# ('Bleach', 501)
# Failed to insert record into mobile table tuple index out of range
# ('The Scorpion King: Book of Souls', 502)
# Failed to insert record into mobile table tuple index out of range
# ('Cats', 503)
# Failed to insert record into mobile table tuple index out of range
# ('Black Water', 504, 16)
# 1
# ('My Hero Academia: Two Heroes', 505)
# Failed to insert record into mobile table tuple index out of range
# ('Edge of Fear', 506)
# Failed to insert record into mobile table tuple index out of range
# ('Badhaai Ho', 507)
# Failed to insert record into mobile table tuple index out of range
# ('Malicious', 508)
# Failed to insert record into mobile table tuple index out of range
# ('After Darkness', 509)
# Failed to insert record into mobile table tuple index out of range
# ('Where Hands Touch', 510, 44)
# 1
# ('The New Romantic', 511, 55)
# 1
# ('Nicky Larson et le parfum de Cupidon', 512)
# Failed to insert record into mobile table tuple index out of range
# ('Bel Canto', 513, 50)
# 1
# ('The Standoff at Sparrow Creek', 514, 62)
# 1
# ('An Elephant Sitting Still', 515, 86)
# 1
# ('Tyrel', 516, 71)
# 1
# ('Swinging Safari', 517, 69)
# 1
# ('Lust Stories', 518)
# Failed to insert record into mobile table tuple index out of range
# ('Slice', 519, 61)
# 1
# ('Batman Ninja', 520)
# Failed to insert record into mobile table tuple index out of range
# ('The Night Sitter', 521)
# Failed to insert record into mobile table tuple index out of range
# ('Mard Ko Dard Nahin Hota', 522)
# Failed to insert record into mobile table tuple index out of range
# ('Kona fer í stríð', 523, 81)
# 1
# ('Padmaavat', 524, 63)
# 1
# ('Hong hai xing dong', 525)
# Failed to insert record into mobile table tuple index out of range
# ('Puzzle', 526, 66)
# 1
# ('Sauvage / Wild', 527, 75)
# 1
# ('Run the Race', 528, 35)
# 1
# ('One Last Night', 529)
# Failed to insert record into mobile table tuple index out of range
# ('Hearts Beat Loud', 530, 65)
# 1
# ('Trautmann', 531)
# Failed to insert record into mobile table tuple index out of range
# ('The Amityville Murders', 532, 35)
# 1
# ('A Kid Like Jake', 533, 60)
# 1
# ('Rojo', 534, 76)
# 1
# ('Kelebekler', 535)
# Failed to insert record into mobile table tuple index out of range
# ('An Evening with Beverly Luff Linn', 536, 54)
# 1
# ('Jonathan', 537, 62)
# 1
# ('An Interview with God', 538)
# Failed to insert record into mobile table tuple index out of range
# ('Braid', 539, 60)
# 1
# ('Clara', 540, 43)
# 1
# ('Soul to Keep', 541)
# Failed to insert record into mobile table tuple index out of range
# ('Batman: Gotham by Gaslight', 542)
# Failed to insert record into mobile table tuple index out of range
# ('UFO', 543)
# Failed to insert record into mobile table tuple index out of range
# ('The Jurassic Games', 544)
# Failed to insert record into mobile table tuple index out of range
# ('El fotógrafo de Mauthausen', 545)
# Failed to insert record into mobile table tuple index out of range
# ('Hevi reissu', 546, 72)
# 1
# ('Un couteau dans le coeur', 547, 69)
# 1
# ('The Debt Collector', 548)
# Failed to insert record into mobile table tuple index out of range
# ('Step Sisters', 549)
# Failed to insert record into mobile table tuple index out of range
# ('Dywizjon 303', 550)
# Failed to insert record into mobile table tuple index out of range
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-428e8ff4dd07> in <module>()
# ----> 1 scrape(201, 2000)
#       2
#
# <ipython-input-7-57749d310e57> in scrape(item_number, end_number)
#      10     while item_number < end_number:
#      11
# ---> 12         response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))
#      13
#      14         soup = BeautifulSoup(response.text, 'html.parser')
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     670
#     671         if not stream:
# --> 672             r.content
#     673
#     674         return r
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/models.py in content(self)
#     814                 self._content = None
#     815             else:
# --> 816                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     817
#     818         self._content_consumed = True
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     736             if hasattr(self.raw, 'stream'):
#     737                 try:
# --> 738                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     739                         yield chunk
#     740                 except ProtocolError as e:
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     592         with self._error_catcher():
#     593             while True:
# --> 594                 self._update_chunk_length()
#     595                 if self.chunk_left == 0:
#     596                     break
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/response.py in _update_chunk_length(self)
#     534         if self.chunk_left is not None:
#     535             return
# --> 536         line = self._fp.fp.readline()
#     537         line = line.split(b';', 1)[0]
#     538         try:
#
# /Users/johnaguero/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/johnaguero/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
item_number = 1
response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))

soup = BeautifulSoup(response.text, 'html.parser')
movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')





movie_containers[0].find('span', class_ = 'lister-item-index unbold text-primary').text.strip(".")

# %%
# def scrape(item_number):
    
    
    
#     response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))
    
#     soup = BeautifulSoup(response.text, 'html.parser')
#     movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
    
    

    

    
#     for container in movie_containers:
#         data = []
#         title = container.h3.a
#         if title:
#             data.append(title.text)
#         else:
#             data.append(None)

#         list_number = container.find('span', class_ = 'lister-item-index unbold text-primary')
#         if list_number:
#             data.append(int(list_number.text.strip(".")))   
#         else:
#             data.append(None)

#         year = container.h3.find('span', class_ = 'lister-item-year text-muted unbold')
#         if year:

#             data.append(year.text.strip("()"))
#         else:
#             data.append(None)

#         runtime = container.find('span', class_ = 'runtime')
#         if runtime:
#             data.append(runtime.text.strip("()"))
#         else:
#             data.append(None)

#         imdb_sc = container.strong
#         if imdb_sc:
#             data.append(float(imdb_sc.text.strip("()")))
#         else:
#             data.append(None)

#         mscore = container.find('span', class_ = 'metascore favorable')
#         if mscore:
#             data.append(int(mscore.text))
#         else:
#             data.append(None)                

#         genres = container.find('span', class_ = 'genre')
#         if genres:
#             data.append(genres.text.strip("\n"))
#         else:
#             data.append(None)                

#         MPAA_rating = container.find('span', class_ = 'certificate')
#         if MPAA_rating:
#             data.append(MPAA_rating.text)
#         else:
#             data.append(None)    


#         director, star = names(container)
#         if director:
#             data.append(director)
#         else:
#             data.append(None)

#         if star:
#             data.append(star)
#         else:
#             data.append(None)                


#         votes, gross = vote_gross(container)

#         if votes:
#             data.append(int(votes.strip(",")) )            
#         else:
#             data.append(None)

#         if gross:
#             data.append(gross)                
#         else:
#             data.append(None)

# %%
# def scrape(item_number):
    
    
    
#     response = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&start={}&ref_=adv_nxt'.format(item_number))
    
#     soup = BeautifulSoup(response.text, 'html.parser')
#     movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
    
    

#     fields['link'] = tag['href']
#     fields['u_id'] = tag['data-id']
#     fields['title'] = tag.text

    
#     for container in movie_containers:
#         fields = {}
#         title = container.h3.a
#         if title:
#             fields['Film title'] = title.text
#         else:
#             data.append(None)

#         list_number = container.find('span', class_ = 'lister-item-index unbold text-primary')
#         if list_number:
#             fields['Imdb 2018 list number'] = (int(list_number.text.strip(".")))   
#         else:
#             data.append(None)

#         year = container.h3.find('span', class_ = 'lister-item-year text-muted unbold')
#         if year:
#             fields['Year released'] = year.text.strip("()")
            

            
#         else:
#             data.append(None)

#         runtime = container.find('span', class_ = 'runtime')
#         if runtime:
#             fields['Runtime'] = runtime.text.strip("()"))
#         else:
#             data.append(None)

#         imdb_sc = container.strong
#         if imdb_sc:
#             fields['Imdb Score'] = float(imdb_sc.text.strip("()"))
#         else:
#             data.append(None)

#         mscore = container.find('span', class_ = 'metascore favorable')
#         if mscore:
#             fields['Metascore'] = (int(mscore.text))
#         else:
#             data.append(None)                

#         genres = container.find('span', class_ = 'genre')
#         if genres:
#             fields['Genres'] = genres.text.strip("\n")
#         else:
#             data.append(None)                

#         MPAA_rating = container.find('span', class_ = 'certificate')
#         if MPAA_rating:
#             fields['MPAA rating'] = MPAA_rating.text
#         else:
#             data.append(None)    


#         directors, stars = names(container)
#         if directors:
#             fields['Director(s)'] = directors
#         else:
#             data.append(None)

#         if stars:
#             fields['Actor(s)'] = stars
#         else:
#             data.append(None)                


#         votes, gross = vote_gross(container)

#         if votes:
#             fields['Votes'] = int(votes.strip(","))           
#         else:
#             data.append(None)

#         if gross:
#             fields['Gross'] = gross                
#         else:
#             data.append(None)

#         store_in_db()
        
#         time.sleep(random.randint(5,30))

# %%
data = ['the dark', 345, 57]
data = tuple(data)
data
