# %%
from requests import get
url = 'https://www.rottentomatoes.com/m/the_ballad_of_buster_scruggs'
response = get(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en"
#       dir="ltr"
#       xmlns:fb="http://www.facebook.com/2008/fbml"
#       xmlns:og="http://opengraphprotocol.org/schema/">
#
#     <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
#
#         <!-- salt=lay-def-02-juRm -->
#         <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#         <meta http-equiv="x-ua-compatible" content="ie=edge">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#
#         <title>The Ballad of Buster Scruggs (2018) - Rotten Tomatoes</title>
#         <meta name="description" content="The Ballad of Buster Scruggs is a six-part Western anthology film, a series of tales about the American frontier told through the unique and incomparable voice of Joel and Ethan Coen. Each chapter tells a distinct story about the American West.">
#
#
# ...

# %%
<span class="mop-ratings-wrap__percentage">
                    91%
                </span>

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
rotten_score = html_soup.find('span', class_ = 'mop-ratings-wrap__percentage').text
rotten_score
# Out:
# '\n                    91%\n                '

# %%
mop-ratings-wrap__percentage

# %%
rotten_scorez = html_soup.find_all('span', class_ = 'mop-ratings-wrap__percentage')

# %%
rotten_score_critics = rotten_scorez[0].text
rotten_score_critics
# Out:
# '\n                    91%\n                '

# %%
rotten_score_audience = rotten_scorez[1].text
rotten_score_audience
# Out:
# '\n                    77%\n                '

# %%
rotten_counts_critics = html_soup.find('small', class_ = 'mop-ratings-wrap__text--small')

# %%
rotten_counts_critics.text
# Out:
# '\n            \n                214\n            \n        '

# %%
rotten_counts_audience = html_soup.find_all('strong', class_ = 'mop-ratings-wrap__text--small')

# %%
rotten_counts_audience[1].text
# Out:
# 'User Ratings: 3,069'

# %%
<meta property="og:title" content="The Ballad of Buster Scruggs (2018)">

# %%
title = html_soup.find('meta', property = 'og:title')

# %%
title
# Out:
# <meta content="The Ballad of Buster Scruggs (2018)" property="og:title"/>
